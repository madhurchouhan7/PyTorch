# %% [markdown]
# # AutoGrad in PyTorch

# %%
def dy_dx(x):
    return 2*x

# %%
dy_dx(3)
# Out:
# 6

# %%
import torch

x = torch.tensor(3.0, requires_grad=True)
y = x**2

# %%
x
# Out:
# tensor(3., requires_grad=True)

# %%
y
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(6.)
