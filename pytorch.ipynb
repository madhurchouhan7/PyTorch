# %% [markdown]
# # PyTorch For Deep Learning

# %%
# import torch 
import torch  # type: ignore
print(torch.__version__)
# Out:
# 2.9.0+cu126

# %%
# Check for GPU availability

if torch.cuda.is_available():
    print("CUDA is available. GPU will be used for computations.")
    print(f"Using GPU: {torch.cuda.get_device_name(0)}")
else:
    print("CUDA is not available. Using CPU for computations.")
# Out:
# CUDA is available. GPU will be used for computations.
# Using GPU: Tesla T4

# %% [markdown]
# ### Creating a Tensor

# %%
 # using empty 
# .empty => create a empty memory tensor
x = torch.empty(2,3)
print(x)
# Out:
# tensor([[0.0000e+00, 0.0000e+00, 1.1351e-43],
#         [0.0000e+00, 7.8805e-19, 0.0000e+00]])

# %%
 # check type
print(type(x))
# Out:
# <class 'torch.Tensor'>

# %%
 # using zeros
y = torch.zeros(2,3)
print(y)
# Out:
# tensor([[0., 0., 0.],
#         [0., 0., 0.]])

# %%
 # using ones
z = torch.ones(2,3)
print(z)
# Out:
# tensor([[1., 1., 1.],
#         [1., 1., 1.]])

# %%
# using rand
# creates tensor with random values between 0 and 1
a = torch.rand(2,3)
print(a)
# Out:
# tensor([[0.8979, 0.7703, 0.3350],
#         [0.2598, 0.6175, 0.9625]])

# %%
 # use of seed
a = torch.rand(2,3)  # generates different random numbers each time
torch.manual_seed(42)  # sets the seed for generating random numbers
print(torch.rand(2,3))
# Out:
# tensor([[0.8823, 0.9150, 0.3829],
#         [0.9593, 0.3904, 0.6009]])

# %%
 # manual seed
torch.manual_seed(30)
print(torch.rand(2,3))
# Out:
# tensor([[0.9007, 0.7464, 0.4716],
#         [0.8738, 0.7403, 0.7840]])

# %%
# using tensors

# create a tensor from a list
t1 = torch.tensor([[1,2,3],[4,5,6]])
print(t1)
# Out:
# tensor([[1, 2, 3],
#         [4, 5, 6]])

# %%
# other ways

# arange 
print("Using  arange : ",torch.arange(0,10,3))
# Out:
# Using  arange :  tensor([0, 3, 6, 9])
